# %%
# %cd /content/
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5/
# %pip install -qr requirements.txt
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10485, done.
# remote: Total 10485 (delta 0), reused 0 (delta 0), pack-reused 10485
# Receiving objects: 100% (10485/10485), 10.69 MiB | 32.98 MiB/s, done.
# Resolving deltas: 100% (7241/7241), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 7.7 MB/s

# %% [markdown]
# ### 데이터 베이스에 사진 넣기

# %%
### install
# !pip install gridfs
# !pip install pymongo
# Out:
# ERROR: Could not find a version that satisfies the requirement gridfs (from versions: none)
# ERROR: No matching distribution found for gridfs
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
### cd
# %cd /content/drive/MyDrive/Colab/yolov5/
# Out:
# /content/drive/MyDrive/Colab/yolov5

# %%
### detected image put drive
z_name = '한성대입구역 5번출구'
source_path = '/content/drive/MyDrive/socar_zones/'+z_name+'/'
# !python detect_car.py --source '{source_path}' --zone_name '{z_name}' --conf 0.6 --weights /content/drive/MyDrive/new/yolov5/runs/train/results18/weights/best.pt /content/drive/MyDrive/models/COCO_car_20ep.pt /content/drive/MyDrive/models/person_detect.pt
### img put DB
# !python img_to_db.py '{z_name}'
# Out:
# detect_car: weights=['/content/drive/MyDrive/models/COCO_car_20ep.pt', '/content/drive/MyDrive/models/person_detect.pt'], source=/content/drive/MyDrive/socar_zones/한성대입구역 5번출구/, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, zone_name=한성대입구역 5번출구
# zone_name 한성대입구역 5번출구
# {'_id': ObjectId('61c9aa36acb986d5c84602c5'), 'zone_name': '한성대입구역 5번출구', 'zone_lat': '37.588143', 'zone_lng': '127.00468000000001', 'zone_address': '서울 성북구 성북동1가 35-44', 'max_car': '20', 'limit_car': '24'}
# YOLOv5 🚀 2021-12-22 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46129818 parameters, 0 gradients, 107.9 GFLOPs
# Fusing layers...
# ...

# %%
z_name = '충정로역 10번출구'
source_path = '/content/drive/MyDrive/socar_zones/'+z_name+'/'
# !python detect_empty.py --source '{source_path}' --zone_name '{z_name}' --conf 0.7 --weights /content/drive/MyDrive/models/9camera_350train.pt /content/drive/MyDrive/models/person_detect.pt

# !python img_to_db.py '{z_name}'
# Out:
# detect_empty: weights=['/content/drive/MyDrive/models/9camera_350train.pt', '/content/drive/MyDrive/models/person_detect.pt'], source=/content/drive/MyDrive/socar_zones/충정로역 10번출구/, imgsz=[640, 640], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, zone_name=충정로역 10번출구
# zone_name 충정로역 10번출구
# {'_id': ObjectId('61c9aab9acb986d5c84605a0'), 'zone_name': '충정로역 10번출구', 'zone_lat': '37.559883', 'zone_lng': '126.963324', 'zone_address': '서울 서대문구 충정로3가 368', 'max_car': '0', 'limit_car': '16'}
# YOLOv5 🚀 2021-12-22 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46129818 parameters, 0 gradients, 107.9 GFLOPs
# Fusing layers...
# ...

# %%
# !python img_to_db.py '{z_name}'
# Out:
# {'_id': ObjectId('61c9aa6cacb986d5c84603f1'), 'zone_name': '아마노 감리신학대학교점', 'zone_lat': '37.56773', 'zone_lng': '126.963272', 'zone_address': '서울 서대문구 냉천동 31', 'max_car': '17', 'limit_car': '23'}
