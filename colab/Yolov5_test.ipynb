# %% [markdown]
# ###YOLO v5 Download

# %%
# %cd /content/
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5/
# %pip install -qr requirements.txt
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10488, done.
# remote: Total 10488 (delta 0), reused 0 (delta 0), pack-reused 10488
# Receiving objects: 100% (10488/10488), 10.65 MiB | 33.76 MiB/s, done.
# Resolving deltas: 100% (7252/7252), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 5.0 MB/s

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5/
# %pip install -qr requirements.txt
# Out:
# /content
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %% [markdown]
# ###YOLO v5 test

# %%
# !python detect.py --weight yolov5s.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/Colab/test/
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Colab/test/, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-155-gdc54ed5 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/6 /content/drive/MyDrive/Colab/test/Test-2.png: 384x640 22 cars, Done. (0.262s)
# image 2/6 /content/drive/MyDrive/Colab/test/Test1.jpg: 448x640 1 person, 47 cars, 17 buss, 2 trucks, Done. (0.297s)
# image 3/6 /content/drive/MyDrive/Colab/test/Test2.jpg: 288x640 19 cell phones, Done. (0.191s)
# image 4/6 /content/drive/MyDrive/Colab/test/Test3.jpg: 352x640 6 cars, 1 suitcase, Done. (0.229s)
# ...

# %%
import yaml
import torch
from IPython.display import Image, clear_output

# %%
Image(filename='runs/detect/exp2/Test-2.png', width=1000)

# %%
Image(filename='runs/detect/exp2/Test1.jpg', width=1000)
# 욜로 모델은 차의 방향에 따라 bus로 인식함

# %%
Image(filename='runs/detect/exp2/Test2.jpg', width=1000)

# %%
Image(filename='runs/detect/exp2/Test3.jpg', width=1000)

# %%
Image(filename='runs/detect/exp2/Test4.jpg', width=1000)

# %%
Image(filename='runs/detect/exp2/Test5.jpg', width=1000)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Yolo v5 large model test

# %%
# !python detect.py --img 640 --weight yolov5l.pt --conf 0.6 --classes 2 --source /content/drive/MyDrive/Colab/test/
# Out:
# detect: weights=['yolov5l.pt'], source=/content/drive/MyDrive/Colab/test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[2], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-184-g6865d19 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46533693 parameters, 0 gradients
# image 1/7 /content/drive/MyDrive/Colab/test/Test-2.png: 384x640 10 cars, Done. (0.018s)
# image 2/7 /content/drive/MyDrive/Colab/test/Test1.jpg: 448x640 12 cars, Done. (0.022s)
# image 3/7 /content/drive/MyDrive/Colab/test/Test2.jpg: 288x640 Done. (0.019s)
# image 4/7 /content/drive/MyDrive/Colab/test/Test3.jpg: 352x640 5 cars, Done. (0.017s)
# ...

# %% [markdown]
# ### Ensemble Test

# %%
# !python detect.py --img 640 --weight /content/drive/MyDrive/models/COCO_car_20ep.pt /content/drive/MyDrive/models/car_detect_aug2_30ep.pt /content/drive/MyDrive/models/car_detect_aug_20ep.pt --conf 0.6 --classes 4 --source /content/drive/MyDrive/Colab/test/
# Out:
# detect: weights=['/content/drive/MyDrive/models/COCO_car_20ep.pt', '/content/drive/MyDrive/models/car_detect_aug2_30ep.pt', '/content/drive/MyDrive/models/car_detect_aug_20ep.pt'], source=/content/drive/MyDrive/Colab/test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[4], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-184-g6865d19 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46129818 parameters, 0 gradients, 107.9 GFLOPs
# Fusing layers...
# Model Summary: 367 layers, 46129818 parameters, 0 gradients, 107.9 GFLOPs
# Fusing layers...
# Model Summary: 367 layers, 46129818 parameters, 0 gradients, 107.9 GFLOPs
# ...

# %%
# !python detect.py --img 640 --weight /content/drive/MyDrive/models/COCO_car_20ep.pt /content/drive/MyDrive/models/car_detect_aug_20ep.pt --conf 0.6 --classes 4 --source /content/drive/MyDrive/Colab/test/test.png
# Out:
# detect: weights=['/content/drive/MyDrive/models/COCO_car_20ep.pt', '/content/drive/MyDrive/models/car_detect_aug_20ep.pt'], source=/content/drive/MyDrive/Colab/test/test.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[4], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-184-g6865d19 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46129818 parameters, 0 gradients, 107.9 GFLOPs
# Fusing layers...
# Model Summary: 367 layers, 46129818 parameters, 0 gradients, 107.9 GFLOPs
# Ensemble created with ['/content/drive/MyDrive/models/COCO_car_20ep.pt', '/content/drive/MyDrive/models/car_detect_aug_20ep.pt']
#
# ...

# %%
# !python detect.py --img 640 --weight /content/drive/MyDrive/models/COCO_car_20ep.pt /content/drive/MyDrive/models/car_detect_aug2_30ep.pt --conf 0.6 --classes 4 --source /content/drive/MyDrive/Colab/test/test.png
# Out:
# detect: weights=['/content/drive/MyDrive/models/COCO_car_20ep.pt', '/content/drive/MyDrive/models/car_detect_aug2_30ep.pt'], source=/content/drive/MyDrive/Colab/test/test.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[4], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-184-g6865d19 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46129818 parameters, 0 gradients, 107.9 GFLOPs
# Fusing layers...
# Model Summary: 367 layers, 46129818 parameters, 0 gradients, 107.9 GFLOPs
# Ensemble created with ['/content/drive/MyDrive/models/COCO_car_20ep.pt', '/content/drive/MyDrive/models/car_detect_aug2_30ep.pt']
#
# ...

# %%
# !python detect.py --img 640 --weight /content/drive/MyDrive/models/car_detect_aug2_30ep.pt /content/drive/MyDrive/models/car_detect_aug_20ep.pt --conf 0.6 --classes 4 --source /content/drive/MyDrive/Colab/test/test.png
# Out:
# detect: weights=['/content/drive/MyDrive/models/car_detect_aug2_30ep.pt', '/content/drive/MyDrive/models/car_detect_aug_20ep.pt'], source=/content/drive/MyDrive/Colab/test/test.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[4], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-184-g6865d19 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46129818 parameters, 0 gradients, 107.9 GFLOPs
# Fusing layers...
# Model Summary: 367 layers, 46129818 parameters, 0 gradients, 107.9 GFLOPs
# Ensemble created with ['/content/drive/MyDrive/models/car_detect_aug2_30ep.pt', '/content/drive/MyDrive/models/car_detect_aug_20ep.pt']
#
# ...
